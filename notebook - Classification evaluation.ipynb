# %%
from evaluation.eval_classification import *

# %%
pc, f = formatResults(filename='classification_output')

# %%
pc
# Out:
#                                 Percent_correct                              \
# Key_Scheme                             BayesNet
# Options                                   K2-P1  K2-P2  K2-P3  K2-P4 RHC-P1
# Experiment            Features
# exp5_kmeans unit_norm features1           12.21  15.36  18.29  19.54  12.21
#                       features2           12.80  16.62  20.03  22.65  12.79
#                       features3           15.88  23.34  26.84         15.85
# exp7_kmeans unit_norm features1           15.44  18.18  19.71  20.43
#                       features2           15.56  18.45  20.26  21.38
#                       features3           16.84  20.50  22.27  22.63
#
#                                                                           \
# Key_Scheme
# Options                         RHC-P2 RHC-P3 TabuS-P1 TabuS-P2 TabuS-P3
# Experiment            Features
# exp5_kmeans unit_norm features1   15.1  16.93    12.21    15.63    15.87
# ...

# %%
pc[3:6]
# Out:
#                                 Percent_correct                              \
# Key_Scheme                             BayesNet
# Options                                   K2-P1  K2-P2  K2-P3  K2-P4 RHC-P1
# Experiment            Features
# exp7_kmeans unit_norm features1           15.44  18.18  19.71  20.43
#                       features2           15.56  18.45  20.26  21.38
#                       features3           16.84  20.50  22.27  22.63
#
#                                                                           \
# Key_Scheme
# Options                         RHC-P2 RHC-P3 TabuS-P1 TabuS-P2 TabuS-P3
# Experiment            Features
# exp7_kmeans unit_norm features1                  15.44             18.54
#                       features2                  15.61             18.42
#                       features3                  16.73             18.97
#
#
# Key_Scheme                               DecisionTable    Logistic
# ...
